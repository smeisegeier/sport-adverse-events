# %% [markdown]
# # convert notebooks to markdown
# - `no_input=True` currently does not work from console

# %%
from pandas_plots.cli import converter

converter.jupyter_to_md(path="./3_description.ipynb", no_input=True)
# Out:
# Converting ./3_description.ipynb to Markdown using dataframe-image python API ..
# └ ✅ Successfully removed CSS rules and updated: ./docs/3_description.md
# └ ℹ️ NO CHANGES: All target chunks already contained the line-separated <br> tag in: ./docs/3_description.md or no targets found.
